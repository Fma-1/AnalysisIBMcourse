# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Exploratory Data Analysis Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# In this module you get to work with the cleaned dataset from the previous module.
#
# In this assignment you will perform the task of exploratory data analysis.
# You will find out the distribution of data, presence of outliers and also determine the correlation between different columns in the dataset.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify the distribution of data in the dataset.
#
# -   Identify outliers in the dataset.
#
# -   Remove outliers from the dataset.
#
# -   Identify correlation between features in the dataset.

# %% [markdown]
# * * *

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import the pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m2_survey_data.csv")

# %% [markdown]
# ## Distribution

# %% [markdown]
# ### Determine how the data is distributed

# %% [markdown]
# The column `ConvertedComp` contains Salary converted to annual USD salaries using the exchange rate on 2019-02-01.
#
# This assumes 12 working months and 50 working weeks.

# %% [markdown]
# Plot the distribution curve for the column `ConvertedComp`.

# %%
# your code goes here

import matplotlib as mlp
import matplotlib.pyplot as plt
import seaborn as sns

x = df[["ConvertedComp"]].dropna(axis=0, inplace= False)


sns.distplot(x, hist=False, kde=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Plot the histogram for the column `ConvertedComp`.

# %%
# your code goes here

sns.distplot(x, hist=True, kde=False, bins=int(180/5), hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:>

# %% [markdown]
# What is the median of the column `ConvertedComp`?

# %%
# your code goes here
print('df median: ', df[["ConvertedComp"]].median(), 'x median: ', x.median())
# Out:
# df median:  ConvertedComp    57745.0
# dtype: float64 x median:  ConvertedComp    57745.0
# dtype: float64

# %% [markdown]
# How many responders identified themselves only as a **Man**?

# %%
# your code goes here
df[(df['Gender']=='Man')]['Gender'].value_counts()
# Out:
# Man    10480
# Name: Gender, dtype: int64

# %% [markdown]
# Find out the  median ConvertedComp of responders identified themselves only as a **Woman**?

# %%
# your code goes here
dfw=df[(df['Gender'] == 'Woman')]
print('median woman ConvertedComp =' , dfw['ConvertedComp'].median())
# Out:
# median woman ConvertedComp = 57708.0

# %% [markdown]
# Give the five number summary for the column `Age`?

# %% [markdown]
# **Double click here for hint**.
#
# <!--
# min,q1,median,q3,max of a column are its five number summary.
# -->

# %%
# your code goes here
df['Age'].describe()
# Out:
# count    11111.000000
# mean        30.778895
# std          7.393686
# min         16.000000
# 25%         25.000000
# 50%         29.000000
# 75%         35.000000
# max         99.000000
# Name: Age, dtype: float64

# %% [markdown]
# Plot a histogram of the column `Age`.

# %%
# your code goes here

sns.distplot(df['Age'], hist=True, kde=False, bins=int(100/8), hist_kws={'edgecolor':'black'})
# Out:
# <AxesSubplot:xlabel='Age'>

# %%
# your code goes here
df[['Age']].plot(kind='box')

plt.title('Box plot of Age')

plt.show()

# %% [markdown]
# ## Outliers

# %% [markdown]
# ### Finding outliers

# %% [markdown]
# Find out if outliers exist in the column `ConvertedComp` using a box plot?

# %%
# your code goes here
df[['ConvertedComp']].plot(kind='box')

plt.title('Box plot of ConvertedComp')

plt.show()

# %% [markdown]
# Find out the Inter Quartile Range for the column `ConvertedComp`.

# %%
# your code goes here
outlier = df[['ConvertedComp']].describe()
Q1 = float(outlies.iloc[4:5,0:1].values[0])
Q3 = float(outlies.iloc[6:7,0:1].values[0])
#Q1.reset_index(drop=True, inplace=True)

IQR = Q3-Q1

IQR
# Out:
# 73132.0

# %% [markdown]
# Find out the upper and lower bounds.

# %%
# your code goes here

upperBounds = Q3 + (1.5 * IQR)
lowerBounds = Q1 - (1.5 * IQR)

print('upperBounds: ', upperBounds, 'lowerBounds: ', lowerBounds)
# Out:
# upperBounds:  209698.0 lowerBounds:  -82830.0

# %% [markdown]
# Identify how many outliers are there in the `ConvertedComp` column.

# %%
# your code goes here
df[(df['ConvertedComp'] > upperBounds) | (df['ConvertedComp'] < lowerBounds)]
#879 rows × 85 columns
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 3              16                     I am a developer by profession      Yes
# 13             32                     I am a developer by profession       No
# 45            100                     I am a developer by profession      Yes
# 46            102                     I am a developer by profession       No
# 60            128  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 11296       24915                     I am a developer by profession      Yes
# 11303       24931                     I am a developer by profession       No
# 11350       25036                     I am a developer by profession      Yes
# 11353       25047                     I am a developer by profession      Yes
# 11369       25086                     I am a developer by profession      Yes
#
# ...

# %% [markdown]
# Create a new dataframe by removing the outliers from the `ConvertedComp` column.

# %%
# your code goes here
df_new = df[(df['ConvertedComp'] <= upperBounds) & (df['ConvertedComp'] >= lowerBounds)]

print('df median:', df['ConvertedComp'].median(), 'df_no_outliers median:', df_new[['ConvertedComp']].median(), 'df_no_outliers mean', df_new[['ConvertedComp']].mean() )
# Out:
# df median: 57745.0 df_no_outliers median: ConvertedComp    52704.0
# dtype: float64 df_no_outliers mean ConvertedComp    59883.208389
# dtype: float64

# %% [markdown]
# ## Correlation

# %% [markdown]
# ### Finding correlation

# %% [markdown]
# Find the correlation between `Age` and all other numerical columns.

# %%
# your code goes here

numerical = ['Respondent', 'CompTotal','ConvertedComp','WorkWeekHrs','CodeRevHrs']

for i in numerical:
    print(df[[i,'Age']].corr())

sns.regplot(x='WorkWeekHrs', y = 'Age', data = df)
plt.ylim(0,)

#df[['Respondent','Age']].corr()
#plt.pcolor(df[df.columns & numerical], cmap='RdBu')
#plt.colorbar()
#plt.show()
#df[df.columns & numerical]
# Out:
#             Respondent       Age
# Respondent    1.000000  0.004041
# Age           0.004041  1.000000
#            CompTotal      Age
# CompTotal    1.00000  0.00697
# Age          0.00697  1.00000
#                ConvertedComp       Age
# ConvertedComp       1.000000  0.105386
# Age                 0.105386  1.000000
#              WorkWeekHrs       Age
# WorkWeekHrs     1.000000  0.036518
# Age             0.036518  1.000000
#             CodeRevHrs       Age
# CodeRevHrs    1.000000 -0.020469
# Age          -0.020469  1.000000
# (0.0, 103.15)

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2023-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
